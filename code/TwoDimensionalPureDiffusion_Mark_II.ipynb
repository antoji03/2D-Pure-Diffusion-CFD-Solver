# %% [markdown]
# # **Two-Dimensional Pure Diffusion - MARK II - Gauss-Seidel Iterative Method**
#
# ---

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import math
import time
# !pip install memory_profiler
# !pip install scipy
from memory_profiler import memory_usage
# Out:
# Requirement already satisfied: memory_profiler in c:\users\anton\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.61.0)
# Requirement already satisfied: psutil in c:\users\anton\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from memory_profiler) (7.0.0)
# Collecting scipy
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\anton\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scipy) (2.2.6)
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ------- -------------------------------- 7.6/41.3 MB 39.3 MB/s eta 0:00:01
#    ------------- -------------------------- 14.2/41.3 MB 35.6 MB/s eta 0:00:01
#    --------------------- ------------------ 22.3/41.3 MB 35.2 MB/s eta 0:00:01
#    ------------------------------ --------- 31.2/41.3 MB 36.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.4/41.3 MB 34.6 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.3 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 30.2 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3

# %% [markdown]
# ## Problem Data

# %%
# Computational Domain
L = 2
H = 1

ncx = 80
ncy = 40
ncell = ncx * ncy

dx = L/ncx
dy = H/ncy

# Cell Center
def cellCenter(i):
  xcell=dx/2+(i%ncx)*dx
  ycell=dy/2+int(i/ncx)*dy
  return xcell,ycell

# k(x,y) Equation

k_ref = 0.15
k_x = 1
k_y = 0

def k_xy(k_ref,k_x,k_y,x,y):
  return k_ref * (k_x * np.cos(np.pi*(2*x/L)) + k_y * np.sin(np.pi * (y/H)))

# Source Term

def Fonte(k_ref,k_x,k_y,x,y):
  return (400*k_ref*k_x*np.pi**2*np.sin((2*np.pi*x)/L)*np.sin((2*np.pi*y)/H + (4*np.pi*x)/L))/L**2 - (800*k_ref*np.pi**2*np.cos((2*np.pi*y)/H + (4*np.pi*x)/L)*(k_x*np.cos((2*np.pi*x)/L) + k_y*np.sin((np.pi*y)/H)))/L**2 - (100*k_ref*k_y*np.pi**2*np.cos((np.pi*y)/H)*np.sin((2*np.pi*y)/H + (4*np.pi*x)/L))/H**2 - (200*k_ref*np.pi**2*np.cos((2*np.pi*y)/H + (4*np.pi*x)/L)*(k_x*np.cos((2*np.pi*x)/L) + k_y*np.sin((np.pi*y)/H)))/H**2

# Partial Derivatives, dT_dx e dT_dy

def dT_dx(x,y,L,H):
  return -(200*np.pi*np.sin((2*np.pi*y)/H + (4*np.pi*x)/L))/L
def dT_dy(x,y,L,H):
  return -(100*np.pi*np.sin((2*np.pi*y)/H + (4*np.pi*x)/L))/H

# %% [markdown]
# ## Analytical Solution

# %%
# Function to compute the analytical solution T(x,y)

def T_analitica(x,y):
  return 50 * np.cos((np.pi*4*x/L) + (np.pi*2*y/H)) + 200

# %% [markdown]
# ## Numerical Simulation and Erros

# %%
import numpy as np
from numpy import linalg as LA

#initialize arrays
A = np.zeros((ncell,ncell))
PHI = np.zeros(ncell)
AW = np.zeros(ncell)
AE = np.zeros(ncell)
AN = np.zeros(ncell)
AS = np.zeros(ncell)
SU = np.zeros(ncell)
SP = np.zeros(ncell)
Error_abs = np.zeros(ncell)
Error_rel = np.zeros(ncell)

#Set method coefficients
for i in range(0, ncell):

    xcell,ycell=cellCenter(i)
    Termo_fonte = - Fonte(k_ref,k_x,k_y,xcell,ycell)
    FI_dT_dx = dT_dx(xcell+dx/2,ycell,L,H)
    FI_dT_dy = dT_dy(xcell,ycell+dy/2,L,H)
    TI_0Y = T_analitica(xcell -dx/2,ycell)
    TI_X0 = T_analitica(xcell,ycell-dy/2)

    k_w = k_xy(k_ref,k_x,k_y,xcell-dx/2,ycell)
    k_e = k_xy(k_ref,k_x,k_y,xcell+dx/2,ycell)
    k_n = k_xy(k_ref,k_x,k_y,xcell,ycell+dy/2)
    k_s = k_xy(k_ref,k_x,k_y,xcell,ycell-dy/2)

    AW[i]=k_w * dy/dx
    AE[i]=k_e * dy/dx
    AS[i]=k_s * dx/dy
    AN[i]=k_n * dx/dy
    SU[i]=Termo_fonte * dx * dy
    SP[i]=0

    if i<ncx: ## First Row, South Boundary, Imposed Temperature, Dirichlet Condition
        AS[i] = 0
        SU[i] += 2 * k_s * TI_X0 * dx/dy
        SP[i] += -2 * k_s * dx/dy

    if i % ncx == 0 : ## First Column, West Boundary, Imposed Temperature, Dirichlet Condition
        AW[i] = 0
        SU[i] += 2 * k_w * TI_0Y * dy/dx
        SP[i] += -2 * k_w * dy/dx

    if (i+1) % ncx == 0 : ##Last column, East Boundary, Imposed Flux, Neumann Condition
        AE[i] = 0
        SU[i] += k_e * FI_dT_dx * dy
        SP[i] += 0

    if i >= (ncell-ncx): ##Last Row, North Boundary, Imposed Flux, Neumann Condition
        AN[i] = 0
        SU[i] += k_n * FI_dT_dy * dx
        SP[i] += 0

# Prepare the coefficients matrix [A]
for i in range(0, ncell):
    icw=i-1
    ice=i+1
    icn=i+ncx
    ics=i-ncx
    if i>=ncx: ##Not in first Row
      A[i,ics]=-AS[i]
    if i % ncx != 0 : ##Not in first column
      A[i,icw]=-AW[i]
    if (i+1) % ncx != 0 : ##Not in Last column
      A[i,ice]=-AE[i]
    if i < (ncell-ncx): ##Not in Last Row
      A[i,icn]=-AN[i]

   # A[i,i]=AW[i]+AE[i]+AN[i]+AS[i]-SP[i] #The Diagonal (Coefficient ap)

#Implementation of the Gauss-Seidel Iterative Method for Numerical Resolution

def gauss_seidel(PHI, AW, AE, AN, AS, SP, SU, ncx, ncy, max_iter=60000, tol=1e-8):
    ncell = ncx * ncy
    for it in range(max_iter):
        PHI_old = PHI.copy()
        for i in range(ncell):
            ap = AW[i] + AE[i] + AN[i] + AS[i] - SP[i]
            phi_w = PHI[i - 1] if i % ncx != 0 else 0
            phi_e = PHI[i + 1] if (i + 1) % ncx != 0 else 0
            phi_s = PHI[i - ncx] if i >= ncx else 0
            phi_n = PHI[i + ncx] if i < ncell - ncx else 0

            PHI[i] = (AW[i] * phi_w + AE[i] * phi_e + AS[i] * phi_s + AN[i] * phi_n + SU[i]) / ap

        # Convergence criterion (Mean Relative Error)
        error = np.linalg.norm(PHI - PHI_old) / np.linalg.norm(PHI)
        if error < tol:
            print(f"Gauss-Seidel convergiu em {it+1} iterações com erro = {error:.2e}")
            break
    else:
        print("Gauss-Seidel não convergiu no número máximo de iterações.")
    return PHI

# Numerical Resolution With Gauss-Seidel Method and Time Measurement
def run_gauss_seidel():
    PHI = np.zeros(ncell)
    PHI = gauss_seidel(PHI, AW, AE, AN, AS, SP, SU, ncx, ncy)
    return PHI

start_time = time.time()
mem_usage, PHI = memory_usage(run_gauss_seidel, retval=True, max_usage=True)
end_time = time.time()

print(f"Tempo de execução: {end_time - start_time:.4f} segundos")
print(f"Memória máxima usada: {mem_usage:.2f} MB")

# Calculate the errors
for i in range(0, ncell):
   xcell,ycell = cellCenter(i)
   Error_abs[i] = abs((PHI[i]-T_analitica(xcell,ycell)))
   Error_rel[i] = abs((PHI[i]-T_analitica(xcell,ycell))/T_analitica(xcell,ycell))

print("Average Absolute Error:",LA.norm(Error_abs)/ncell)
print("Average Relative Error:",LA.norm(Error_rel)/ncell)
# Out:
# Gauss-Seidel convergiu em 13980 iterações com erro = 1.00e-08
# Tempo de execução: 70.9916 segundos
# Memória máxima usada: 107.83 MB
# Average Absolute Error: 0.0027021887578749224
# Average Relative Error: 1.5176027014703957e-05

# %% [markdown]
# ## Calculation of the Analytical Solution for all cells

# %%
#Create new variable to store the Analytical solution
PHI_ana = np.zeros(ncell)

# Calculate Analytical solution values
for i in range(0, ncell):
    xcell,ycell = cellCenter(i)
    PHI_ana[i]=T_analitica(xcell,ycell)

# %% [markdown]
# ## Plot the Graph

# %%
def vec2Grid(var, nx, ny):
    z = np.zeros((ny, nx))  # (linhas, colunas)
    for i in range(len(var)):
        z[int(i / nx), i % nx] = var[i]
    return z

# %%
import matplotlib
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

y, x = np.mgrid[slice(0, H + dy, dy),
                slice(0, L + dx, dx)]

#print(x
#print(y)
figScl=10
fig, axs = plt.subplots(2, 2,figsize=(figScl*L/H,figScl*H/L))

ax = axs[0, 0]
z = vec2Grid(PHI,ncx,ncy)
#print(z)
Var_min, Var_max = np.abs(PHI).min(), np.abs(PHI).max()
c = ax.pcolor(x, y, z, cmap='jet', vmin=Var_min, vmax=Var_max)
ax.set_title('Numerical Solution')
fig.colorbar(c, ax=ax)

ax = axs[0, 1]
z = vec2Grid(PHI_ana,ncx,ncy)
#print(z)
Var_min, Var_max = np.abs(PHI_ana).min(), np.abs(PHI_ana).max()
c = ax.pcolor(x, y, z, cmap='jet', vmin=Var_min, vmax=Var_max)
ax.set_title('Analytical Solution')
fig.colorbar(c, ax=ax)

ax = axs[1, 0]
z = vec2Grid(Error_abs,ncx,ncy)
Var_min, Var_max = np.abs(Error_abs).min(), np.abs(Error_abs).max()
c = ax.pcolor(x, y, z, cmap='jet', vmin=Var_min, vmax=Var_max)
ax.set_title('Absolute Error')
fig.colorbar(c, ax=ax)

ax = axs[1, 1]
z = vec2Grid(Error_rel,ncx,ncy)
Var_min, Var_max = np.abs(Error_rel).min(), np.abs(Error_rel).max()
c = ax.pcolor(x, y, z, cmap='jet', vmin=Var_min, vmax=Var_max)
ax.set_title('Relative Error')
fig.colorbar(c, ax=ax)

fig.tight_layout()

plt.show()
